# %%
# 加载包
import scanpy as sc
import pandas as pd

# %%
# # 提取cell2location注释好的信息并保存为csv文件
# adata_vis = sc.read_h5ad('/home/zhangyinan/TXL_new/4_cell2location/Integrate/Control3_Model1_Treatment2/result/celltype/cell2location_map/sp.h5ad')

# %%
# 读取celltype信息
anno_cell = pd.read_csv("/home/zhangyinan/TXL_new/4_cell2location/Integrate/Control3_Model1_Treatment2/result/celltype/celltype_first.csv", index_col=0)
anno_cell.head()

# 读取subtype信息
anno_sub = pd.read_csv("/home/zhangyinan/TXL_new/4_cell2location/Integrate/Control3_Model1_Treatment2/result/subtype_202507/subtype_first.csv", index_col=0)
anno_sub.head()

# 读取singleR数据
anno_sin = pd.read_csv("/home/zhangyinan/TXL_new/2_annotation/Control3_Model1_Treatment2/result/anno_single_c3_m1_t2.csv", index_col = 0)
anno_sin.head()
# Out:
#                     scores.Adipocytes  scores.Astrocytes  scores.B.cells  \
# AAACAAGTATCTCCCA-1           0.230437           0.274339        0.115712
# AAACACCAATAACTGC-1           0.231962           0.385859        0.115986
# AAACAGAGCGACTCCT-1           0.176116           0.347970        0.085965
# AAACAGCTTTCAGAAG-1           0.183732           0.318791        0.099646
# AAACAGGGTCTATATT-1           0.197678           0.352497        0.099137
#
#                     scores.Cardiomyocytes  scores.Dendritic.cells  \
# AAACAAGTATCTCCCA-1               0.200548                0.128364
# AAACACCAATAACTGC-1               0.230729                0.083515
# AAACAGAGCGACTCCT-1               0.163232                0.038968
# AAACAGCTTTCAGAAG-1               0.174969                0.073861
# AAACAGGGTCTATATT-1               0.194949                0.060096
#
#                     scores.Endothelial.cells  scores.Epithelial.cells  \
# ...

# %%
## 新建一个注释文件
# 创建一个新的 DataFrame anno，并以 anno_sin 的索引为索引
anno = pd.DataFrame(index=anno_cell.index)

# 添加列
anno["cell_type_c2l"] = anno_cell.loc[anno.index, "cell_type"]
anno["sub_type_c2l"] = anno_sub.loc[anno.index, "cell_type"]
anno["singleR"] = anno_sin.loc[anno.index, "labels"]

# %%
anno.to_csv('/home/zhangyinan/TXL_new/4_cell2location/Integrate/Control3_Model1_Treatment2/result/annotation_202507.csv', index = True)

# %%
# adata_vis.obs["cell_type_c2l"] = anno_cell["cell_type"]
# adata_vis.obs["sub_type_c2l"] = anno_sub["cell_type"]

# %%
# adata_vis.write("/home/zhangyinan/TXL_new/4_cell2location/Integrate/Control3_Model1_Treatment2/data_celltype/c3_m1_t2_cell_sub_first.h5ad")
