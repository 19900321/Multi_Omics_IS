# %% [markdown]
# ## 加载R包

# %%
library(CellChat)
library(patchwork)
# Out:
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: igraph
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Loading required package: ggplot2

# %% [markdown]
# ## 读取数据并进行样本分割

# %%
adata = readRDS("/home/zhangyinan/TXL_new/1_basic_data_processing/Integrate/result/ST_Integrate.rds")
adata
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     intersect
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, t
#
#
# Loading required package: Seurat
#
#
# Attaching package: ‘Seurat’
#
#
# The following object is masked from ‘package:igraph’:
#
#     components
# An object of class Seurat
# 48702 features across 5435 samples within 3 assays
# Active assay: integrated (2000 features, 2000 variable features)
#  2 layers present: data, scale.data
#  2 other assays present: Spatial, SCT
#  3 dimensional reductions calculated: pca, umap, tsne
#  2 spatial fields of view present: control3_model1_treatment2 control5_model2_treatment3

# %%
anno_c3m1t2 = read.csv("/home/zhangyinan/TXL_new/4_cell2location/Integrate/Control3_Model1_Treatment2/result/annotation_202507.csv",row.names = 1)
dim(anno_c3m1t2)
# Out:
# [1] 2912    3

# %%
# 加载位置信息
source_c3m1t2 = read.csv('/home/zhangyinan/TXL_new/1_basic_data_processing/Control3_Model1_Treatment2/result/source_c3_m1_t2.csv',row.names = 1)
dim(source_c3m1t2)

anno_c3m1t2 = anno_c3m1t2[source_c3m1t2$source %in% c("control3", "model1", "treatment2"), ]
dim(anno_c3m1t2)

rownames(anno_c3m1t2) <- paste0(rownames(anno_c3m1t2), "_1")
head(anno_c3m1t2)
# Out:
# [1] 2912    4
# [1] 2769    3
#                      cell_type_c2l sub_type_c2l            singleR
# AAACAAGTATCTCCCA-1_1 Neurons       Fibroblasts             Neurons
# AAACACCAATAACTGC-1_1 Neurons       Glutamatergic Neurons   Neurons
# AAACAGAGCGACTCCT-1_1 Neurons       GABAergic Neurons       Neurons
# AAACAGCTTTCAGAAG-1_1 Neurons       Mature Oligodendrocytes Oligodendrocytes
# AAACAGGGTCTATATT-1_1 Neurons       GABAergic Neurons       Neurons
# AAACATGGTGAGAGGA-1_1 Neurons       Glutamatergic Neurons   Neurons

# %%
anno_c5m2t3 = read.csv("/home/zhangyinan/TXL_new/4_cell2location/Integrate/Control5_Model2_Treatment3/result/annotation_202507.csv",row.names = 1)
dim(anno_c5m2t3)

rownames(anno_c5m2t3) <- paste0(rownames(anno_c5m2t3), "_2")
head(anno_c5m2t3)
# Out:
# [1] 2666    3
#                      cell_type_c2l    sub_type_c2l            singleR
# AAACAATCTACTAGCA-1_2 Neurons          Glutamatergic Neurons   Neurons
# AAACACCAATAACTGC-1_2 Astrocytes       Astrocytes              Neurons
# AAACAGAGCGACTCCT-1_2 Neurons          Glutamatergic Neurons   Neurons
# AAACCACTACACAGAT-1_2 Oligodendrocytes Mature Oligodendrocytes Oligodendrocytes
# AAACCGGGTAGGTACC-1_2 Neurons          GABAergic Neurons       Neurons
# AAACCGTTCGTCCAGG-1_2 Neurons          Mature Oligodendrocytes Oligodendrocytes

# %%
# 合并注释表格
anno = rbind(anno_c3m1t2, anno_c5m2t3)
dim(anno)
# Out:
# [1] 5435    3

# %%
identical(rownames(adata@meta.data), rownames(anno))
# Out:
# [1] TRUE

# %%
# 添加注释信息至seurat对象meta.data中
adata@meta.data <- cbind(adata@meta.data, anno[, 1:3])
head(adata@meta.data)
# Out:
#                      orig.ident    nCount_Spatial nFeature_Spatial nCount_SCT
# AAACAAGTATCTCCCA-1_1 SeuratProject  5051          2102             10082
# AAACACCAATAACTGC-1_1 SeuratProject 33162          6191             10691
# AAACAGAGCGACTCCT-1_1 SeuratProject 11880          3517             11149
# AAACAGCTTTCAGAAG-1_1 SeuratProject  7773          2819              9859
# AAACAGGGTCTATATT-1_1 SeuratProject 16518          4538             11413
# AAACATGGTGAGAGGA-1_1 SeuratProject 39549          7064             11229
#                      nFeature_SCT percent.mt SCT_snn_res.0.8 seurat_clusters
# AAACAAGTATCTCCCA-1_1 2286         10.04353   0               0
# AAACACCAATAACTGC-1_1 3585         16.54515   8               9
# AAACAGAGCGACTCCT-1_1 3509         19.60293   4               5
# AAACAGCTTTCAGAAG-1_1 2813         17.02646   3               1
# AAACAGGGTCTATATT-1_1 4418         12.95063   5               11
# AAACATGGTGAGAGGA-1_1 4251         10.30823   8               9
#                      slice                      source     Source
# AAACAAGTATCTCCCA-1_1 control3_model1_treatment2 model1     model
# AAACACCAATAACTGC-1_1 control3_model1_treatment2 treatment2 treatment
# AAACAGAGCGACTCCT-1_1 control3_model1_treatment2 control3   control
# AAACAGCTTTCAGAAG-1_1 control3_model1_treatment2 treatment2 treatment
# AAACAGGGTCTATATT-1_1 control3_model1_treatment2 treatment2 treatment
# AAACATGGTGAGAGGA-1_1 control3_model1_treatment2 treatment2 treatment
#                      percent_mito integrated_snn_res.0.8 cell_type_c2l
# AAACAAGTATCTCCCA-1_1 10.04353     0                      Neurons
# AAACACCAATAACTGC-1_1 16.54515     9                      Neurons
# AAACAGAGCGACTCCT-1_1 19.60293     5                      Neurons
# AAACAGCTTTCAGAAG-1_1 17.02646     1                      Neurons
# AAACAGGGTCTATATT-1_1 12.95063     11                     Neurons
# AAACATGGTGAGAGGA-1_1 10.30823     9                      Neurons
#                      sub_type_c2l            singleR
# AAACAAGTATCTCCCA-1_1 Fibroblasts             Neurons
# AAACACCAATAACTGC-1_1 Glutamatergic Neurons   Neurons
# AAACAGAGCGACTCCT-1_1 GABAergic Neurons       Neurons
# AAACAGCTTTCAGAAG-1_1 Mature Oligodendrocytes Oligodendrocytes
# AAACAGGGTCTATATT-1_1 GABAergic Neurons       Neurons
# AAACATGGTGAGAGGA-1_1 Glutamatergic Neurons   Neurons

# %%
VlnPlot(adata, features = c("Sema4d","Plxnb1","Plxnb2"), group.by = "Source", pt.size = 0, ncol = 1)
# Out:
# plot without title

# %%
table(adata$source)
# Out:
#   control3   control5     model1     model2 treatment2 treatment3
#        700        891       1377        950        692        825

# %%
adata_control3 = subset(adata, subset = source == "control3")
adata_control5 = subset(adata, subset = source == "control5")
# Out:
# Warning message:
# “Not validating Centroids objects”
# Warning message:
# “Not validating Centroids objects”
# Warning message:
# “Not validating FOV objects”
# Warning message:
# “Not validating FOV objects”
# Warning message:
# “Not validating FOV objects”
# Warning message:
# “Not validating FOV objects”
# Warning message:
# “Not validating FOV objects”
# Warning message:
# “Not validating FOV objects”
# Warning message:
# “Not validating Seurat objects”
# Warning message:
# “Not validating Seurat objects”
# Warning message:
# “Not validating Seurat objects”
# Warning message:
# “Not validating Centroids objects”
# Warning message:
# “Not validating Centroids objects”
# Warning message:
# “Not validating FOV objects”
# Warning message:
# “Not validating FOV objects”
# Warning message:
# “Not validating FOV objects”
# Warning message:
# “Not validating FOV objects”
# Warning message:
# “Not validating FOV objects”
# Warning message:
# “Not validating FOV objects”
# Warning message:
# “Not validating Seurat objects”

# %% [markdown]
# ## 创建cellchat对象前处理

# %%
# 提取表达矩阵
data.input1 = Seurat::GetAssayData(adata_control3, slot = "data", assay = "SCT")
data.input2 = Seurat::GetAssayData(adata_control5, slot = "data", assay = "SCT")
# Out:
# Warning message:
# “The `slot` argument of `GetAssayData()` is deprecated as of SeuratObject 5.0.0.
# ℹ Please use the `layer` argument instead.”

# %%
# 取交集基因
genes.common <- intersect(rownames(data.input1), rownames(data.input2))
data.input <- cbind(data.input1[genes.common, ], data.input2[genes.common, ])

# %%
Idents(adata_control3) = "sub_type_c2l"
Idents(adata_control5) = "sub_type_c2l"

# 定义meta数据
meta1 = data.frame(labels = Idents(adata_control3), samples = "control3")
meta2 = data.frame(labels = Idents(adata_control5), samples = "control5")
meta <- rbind(meta1, meta2)
rownames(meta) <- colnames(data.input)

# %%
# 设置factor水平
meta$labels <- factor(meta$labels, levels = levels(Idents(adata_control5)))
meta$samples <- factor(meta$samples, levels = c("control3", "control5"))

# %%
# 空间坐标
spatial.locs1 = Seurat::GetTissueCoordinates(adata_control3, scale = NULL, cols = c("imagerow", "imagecol")) 
spatial.locs1 = spatial.locs1[, -3]

spatial.locs2 = Seurat::GetTissueCoordinates(adata_control5, scale = NULL, cols = c("imagerow", "imagecol")) 
spatial.locs2 = spatial.locs2[, -3]

# 合并
spatial.locs <- rbind(spatial.locs1, spatial.locs2)
rownames(spatial.locs) <- colnames(data.input)

# %%
scalefactors1 = jsonlite::fromJSON(txt = file.path("/home/zhangyinan/TXL_new/1_basic_data_processing/Control3_Model1_Treatment2/data/control3--model1--Treatment2/spatial", 'scalefactors_json.json'))
spot.size = 55
conversion.factor1 = spot.size / scalefactors1$spot_diameter_fullres
spatial.factors1 = data.frame(ratio = conversion.factor1, tol = spot.size/2)

scalefactors2 = jsonlite::fromJSON(txt = file.path("//home/zhangyinan/TXL_new/1_basic_data_processing/Control5_Model2_Treatment3/data/control5_model2_Treatment3/spatial", 'scalefactors_json.json'))
spot.size = 55
conversion.factor2 = spot.size / scalefactors2$spot_diameter_fullres
spatial.factors2 = data.frame(ratio = conversion.factor2, tol = spot.size/2)

# 合并两个样本的 scale factor
spatial.factors <- rbind(spatial.factors1, spatial.factors2)
rownames(spatial.factors) <- c("control3", "control5")

# %% [markdown]
# ## 创建cellchat对象

# %%
cellchat <- createCellChat(object = data.input, meta = meta, group.by = "labels",
                           datatype = "spatial", coordinates = spatial.locs, spatial.factors = spatial.factors)
# Out:
# [1] "Create a CellChat object from a data matrix"
# Create a CellChat object from spatial transcriptomics data...
# Set cell identities for the new CellChat object
# The cell groups used for CellChat analysis are  Glutamatergic Neurons, Mature Oligodendrocytes, Astrocytes, Fibroblasts, Oligodendrocyte Precursor Cells, GABAergic Neurons, Ependymal cell

# %%
cellchat
# Out:
# An object of class CellChat created from a single dataset
#  16142 genes.
#  1591 cells.
# CellChat analysis of spatial data! The input spatial locations are
#                      x_cent y_cent
# AAACAGAGCGACTCCT-1_1   3629  10918
# AAACGCCCGAGATCGG-1_1   1905  12309
# AAACTAACGTGGCGAC-1_1   2596  12507
# AAACTCGTGATATAAG-1_1   5186  12801
# AAAGGTAAGCTGTACC-1_1   2940  12109
# AAATAACCATACGGGA-1_1   3629  10323

# %%
# Set the ligand-receptor interaction database
CellChatDB <- CellChatDB.mouse
CellChatDB.use <- CellChatDB 
cellchat@DB <- CellChatDB.use

# %%
# subset the expression data of signaling genes for saving computation cost
cellchat <- subsetData(cellchat) # This step is necessary even if using the whole database
future::plan("multisession", workers = 20) 
cellchat <- identifyOverExpressedGenes(cellchat)
cellchat <- identifyOverExpressedInteractions(cellchat)
#> The number of highly variable ligand-receptor pairs used for signaling inference is 422
# Out:
# The number of highly variable ligand-receptor pairs used for signaling inference is 1383

# %%
cellchat <- computeCommunProb(cellchat, 
                              type = "truncatedMean", trim = 0.1, 
                              distance.use = TRUE, 
                            #   interaction.range = 250, 
                              scale.distance = 1,
                            #   contact.dependent = TRUE, 
                              contact.range = 10)
# Out:
# truncatedMean is used for calculating the average gene expression per cell group.
# Error in computeCommunProb(cellchat, type = "truncatedMean", trim = 0.1, : Please check `unique(object@idents)` and ensure that the factor levels are correct!
#          You may need to drop unused levels using 'droplevels' function. e.g.,
#          `meta$labels = droplevels(meta$labels, exclude = setdiff(levels(meta$labels),unique(meta$labels)))`
# Traceback:
#
# 1. computeCommunProb(cellchat, type = "truncatedMean", trim = 0.1,
#  .     distance.use = TRUE, scale.distance = 1, contact.range = 10)
# 2. stop("Please check `unique(object@idents)` and ensure that the factor levels are correct!\n         You may need to drop unused levels using 'droplevels' function. e.g.,\n         `meta$labels = droplevels(meta$labels, exclude = setdiff(levels(meta$labels),unique(meta$labels)))`")

# %%
# 默认情况下，每个细胞组中用于细胞间通信所需的最小细胞数为10
cellchat <- filterCommunication(cellchat, min.cells = 10)
# 在信号通路水平上推断细胞间通讯
cellchat <- computeCommunProbPathway(cellchat)
# 计算聚合的 cell-cell 通信网络
cellchat <- aggregateNet(cellchat)
# Out:
# The cell-cell communication related with the following cell groups are excluded due to the few number of cells:  Oligodendrocyte Precursor Cells, Ependymal cell ! 	5.5% interactions are removed!

# %%
saveRDS(cellchat, file = "/home/zhangyinan/TXL_new/13_cell_chat/integrate/result/cellchat_control.rds")

# %%
cellchat = readRDS("/home/zhangyinan/TXL_new/13_cell_chat/integrate/result/cellchat_control_2.rds")

# %%
groupSize <- as.numeric(table(cellchat@idents))
par(mfrow = c(1,2), xpd=TRUE)
netVisual_circle(cellchat@net$count, vertex.weight = rowSums(cellchat@net$count), weight.scale = T, label.edge= F, title.name = "Number of interactions")
netVisual_circle(cellchat@net$weight, vertex.weight = rowSums(cellchat@net$weight), weight.scale = T, label.edge= F, title.name = "Interaction weights/strength")
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
netVisual_heatmap(cellchat, measure = "count", color.heatmap = "Blues")
#> Do heatmap based on a single object
# Out:
# Do heatmap based on a single object
# plot without title

# %% [markdown]
# ##  Visualization of cell-cell communication network

# %%
pathways.show <- c("SEMA4") 
# Circle plot
par(mfrow=c(1,1), xpd=TRUE)
netVisual_aggregate(cellchat, signaling = pathways.show, layout = "circle")
# Out:
# Plot with title “”
# Plot with title “”

# %%
# Spatial plot
par(mfrow=c(1,1))
netVisual_aggregate(cellchat, signaling = pathways.show, sample.use = "control3", layout = "spatial", edge.width.max = 2, vertex.size.max = 1, alpha.image = 0.2, vertex.label.cex = 0)
# Out:
# plot without title

# %%
# Compute the network centrality scores
cellchat <- netAnalysis_computeCentrality(cellchat, slot.name = "netP") # the slot 'netP' means the inferred intercellular communication network of signaling pathways
# Visualize the computed centrality scores using heatmap, allowing ready identification of major signaling roles of cell groups
par(mfrow=c(1,1))
netAnalysis_signalingRole_network(cellchat, signaling = pathways.show, width = 8, height = 2.5, font.size = 10)
# Out:
# plot without title

# %%
# USER can show this information on the spatial transcriptomics when visualizing a signaling network, e.g., bigger circle indicates larger incoming signaling
par(mfrow=c(1,1))
netVisual_aggregate(cellchat, signaling = pathways.show, sample.use = "control3", layout = "spatial", edge.width.max = 2, alpha.image = 0.2, vertex.weight = "incoming", vertex.size.max = 6, vertex.label.cex = 0)
# Out:
# plot without title

# %%
p = netAnalysis_contribution(cellchat, signaling = pathways.show)
p
# Out:
# plot without title

# %%
p$data
# Out:
#               name             contribution
# SEMA4A_PLXNB2 Sema4a  - Plxnb2 0.31219662
# SEMA4D_PLXNB1 Sema4d  - Plxnb1 0.31159239
# SEMA4D_PLXNB3 Sema4d  - Plxnb3 0.17020173
# SEMA4A_PLXNB1 Sema4a  - Plxnb1 0.13400800
# SEMA4C_PLXNB2 Sema4c  - Plxnb2 0.03648472
# SEMA4G_PLXNB2 Sema4g  - Plxnb2 0.03551654
# 1             1                0.00000000
# 2             2                0.00000000
# 3             3                0.00000000
# 4             4                0.00000000

# %%
# Take an input of a few genes
spatialFeaturePlot(cellchat, features = c("Sema4d","Plxnb2"), sample.use = "control3", point.size = 0.8, color.heatmap = "Reds", direction = 1)
# Out:
# plot without title

# %%
# Take an input of a few genes
spatialFeaturePlot(cellchat, features = c("Sema4d","Plxnb2"), sample.use = "control5", point.size = 0.8, color.heatmap = "Reds", direction = 1)
# Out:
# plot without title

# %%
head(cellchat@LR$LRsig)
# Out:
#                     interaction_name    pathway_name ligand receptor
# TGFB2_TGFBR1_TGFBR2 TGFB2_TGFBR1_TGFBR2 TGFb         Tgfb2  TGFbR1_R2
# TGFB2_ACVR1B_TGFBR2 TGFB2_ACVR1B_TGFBR2 TGFb         Tgfb2  ACVR1B_TGFbR2
# TGFB2_ACVR1C_TGFBR2 TGFB2_ACVR1C_TGFBR2 TGFb         Tgfb2  ACVR1C_TGFbR2
# TGFB2_ACVR1_TGFBR1  TGFB2_ACVR1_TGFBR1  TGFb         Tgfb2  ACVR1_TGFbR
# BMP4_BMPR1A_ACVR2A  BMP4_BMPR1A_ACVR2A  BMP          Bmp4   BMPR1A_ACVR2A
# BMP4_BMPR1A_ACVR2B  BMP4_BMPR1A_ACVR2B  BMP          Bmp4   BMPR1A_ACVR2B
#                     agonist      antagonist      co_A_receptor
# TGFB2_TGFBR1_TGFBR2 TGFb agonist TGFb antagonist
# TGFB2_ACVR1B_TGFBR2 TGFb agonist TGFb antagonist
# TGFB2_ACVR1C_TGFBR2 TGFb agonist TGFb antagonist
# TGFB2_ACVR1_TGFBR1
# BMP4_BMPR1A_ACVR2A               BMP antagonist
# BMP4_BMPR1A_ACVR2B               BMP antagonist
#                     co_I_receptor            annotation
# TGFB2_TGFBR1_TGFBR2 TGFb inhibition receptor Secreted Signaling
# TGFB2_ACVR1B_TGFBR2 TGFb inhibition receptor Secreted Signaling
# TGFB2_ACVR1C_TGFBR2 TGFb inhibition receptor Secreted Signaling
# TGFB2_ACVR1_TGFBR1                           Secreted Signaling
# BMP4_BMPR1A_ACVR2A  BMP inhibition receptor  Secreted Signaling
# BMP4_BMPR1A_ACVR2B  BMP inhibition receptor  Secreted Signaling
#                     interaction_name_2       ⋯ receptor.symbol
# TGFB2_TGFBR1_TGFBR2 Tgfb2  - (Tgfbr1+Tgfbr2) ⋯ Tgfbr1, Tgfbr2
# TGFB2_ACVR1B_TGFBR2 Tgfb2  - (Acvr1b+Tgfbr2) ⋯ Acvr1b, Tgfbr2
# TGFB2_ACVR1C_TGFBR2 Tgfb2  - (Acvr1c+Tgfbr2) ⋯ Acvr1c, Tgfbr2
# TGFB2_ACVR1_TGFBR1  Tgfb2  - (Acvr1+Tgfbr1)  ⋯ Acvr1, Tgfbr1, Tgfbr2
# BMP4_BMPR1A_ACVR2A  Bmp4  - (Bmpr1a+Acvr2a)  ⋯ Bmpr1a, Acvr2a
# BMP4_BMPR1A_ACVR2B  Bmp4  - (Bmpr1a+Acvr2b)  ⋯ Bmpr1a, Acvr2b
#                     receptor.family
# TGFB2_TGFBR1_TGFBR2 Protein kinase superfamily, TKL Ser/Thr protein kinase
# TGFB2_ACVR1B_TGFBR2 Protein kinase superfamily, TKL Ser/Thr protein kinase
# TGFB2_ACVR1C_TGFBR2 Protein kinase superfamily, TKL Ser/Thr protein kinase
# TGFB2_ACVR1_TGFBR1  Protein kinase superfamily, TKL Ser/Thr protein kinase
# BMP4_BMPR1A_ACVR2A  Protein kinase superfamily, TKL Ser/Thr protein kinase
# BMP4_BMPR1A_ACVR2B  Protein kinase superfamily, TKL Ser/Thr protein kinase
#                     receptor.location
# TGFB2_TGFBR1_TGFBR2 Cell membrane, Secreted, Membrane raft, Cell surface, Cell junction, Tight junction
# TGFB2_ACVR1B_TGFBR2 Cell membrane, Secreted, Membrane raft
# TGFB2_ACVR1C_TGFBR2 Cell membrane, Secreted, Membrane raft, Membrane
# TGFB2_ACVR1_TGFBR1  Cell membrane, Secreted, Membrane raft, Membrane, Cell surface, Cell junction, Tight junction
# BMP4_BMPR1A_ACVR2A  Membrane, Cell membrane, Cell surface
# BMP4_BMPR1A_ACVR2B  Cell membrane, Cell surface
#                     receptor.keyword
# TGFB2_TGFBR1_TGFBR2 Membrane, Secreted, Disulfide bond, Kinase, Transmembrane, Differentiation, ATP-binding, Receptor, Alternative splicing, Aortic aneurysm, Transferase, Glycoprotein, Manganese, Disease variant, Growth regulation, Signal, Reference proteome, Metal-binding, Transmembrane helix, Hereditary nonpolyposis colorectal cancer, Cell membrane, Phosphoprotein, Direct protein sequencing, Apoptosis, Craniosynostosis, Serine/threonine-protein kinase, 3D-structure, Nucleotide-binding, Magnesium, Tight junction, Isopeptide bond, Cell junction, Ubl conjugation
# TGFB2_ACVR1B_TGFBR2 Membrane, Secreted, Disulfide bond, Kinase, Transmembrane, Differentiation, ATP-binding, Receptor, Alternative splicing, Aortic aneurysm, Transferase, Glycoprotein, Manganese, Disease variant, Growth regulation, Signal, Reference proteome, Metal-binding, Transmembrane helix, Hereditary nonpolyposis colorectal cancer, Cell membrane, Phosphoprotein, Direct protein sequencing, Apoptosis, Craniosynostosis, Serine/threonine-protein kinase, 3D-structure, Nucleotide-binding, Magnesium, Ubl conjugation
# TGFB2_ACVR1C_TGFBR2 Membrane, Secreted, Disulfide bond, Kinase, Transmembrane, Differentiation, ATP-binding, Receptor, Alternative splicing, Aortic aneurysm, Transferase, Glycoprotein, Manganese, Disease variant, Growth regulation, Signal, Reference proteome, Metal-binding, Transmembrane helix, Hereditary nonpolyposis colorectal cancer, Cell membrane, Phosphoprotein, Direct protein sequencing, Apoptosis, Craniosynostosis, Serine/threonine-protein kinase, 3D-structure, Nucleotide-binding, Magnesium
# TGFB2_ACVR1_TGFBR1  Membrane, Secreted, Disulfide bond, Kinase, Transmembrane, Differentiation, ATP-binding, Receptor, Alternative splicing, Aortic aneurysm, Transferase, Glycoprotein, Manganese, Disease variant, Growth regulation, Signal, Reference proteome, Metal-binding, Transmembrane helix, Hereditary nonpolyposis colorectal cancer, Cell membrane, Phosphoprotein, Direct protein sequencing, Apoptosis, Craniosynostosis, Serine/threonine-protein kinase, 3D-structure, Nucleotide-binding, Magnesium, Tight junction, Isopeptide bond, Cell junction, Ubl conjugation
# BMP4_BMPR1A_ACVR2A  Membrane, Disulfide bond, Transmembrane, Kinase, ATP-binding, Receptor, Alternative splicing, Transferase, Glycoprotein, Manganese, Signal, Reference proteome, Metal-binding, Transmembrane helix, Serine/threonine-protein kinase, 3D-structure, Nucleotide-binding, Magnesium, Disease variant, Cell membrane
# BMP4_BMPR1A_ACVR2B  Membrane, Disulfide bond, Transmembrane, Kinase, ATP-binding, Receptor, Alternative splicing, Heterotaxy, Transferase, Glycoprotein, Manganese, Disease variant, Signal, Reference proteome, Metal-binding, Transmembrane helix, Cell membrane, Phosphoprotein, Serine/threonine-protein kinase, 3D-structure, Nucleotide-binding, Magnesium
#                     receptor.surfaceome_main receptor.surfaceome_sub
# TGFB2_TGFBR1_TGFBR2 Receptors                Act.TGFB;Kinase
# TGFB2_ACVR1B_TGFBR2 Receptors                Act.TGFB;Kinase
# TGFB2_ACVR1C_TGFBR2 Receptors                Act.TGFB;Kinase
# TGFB2_ACVR1_TGFBR1  Receptors                Act.TGFB;Kinase
# BMP4_BMPR1A_ACVR2A  Receptors                Act.TGFB;Kinase
# BMP4_BMPR1A_ACVR2B  Receptors                Act.TGFB;Kinase
#                     receptor.adhesome receptor.secreted_type
# TGFB2_TGFBR1_TGFBR2
# TGFB2_ACVR1B_TGFBR2
# TGFB2_ACVR1C_TGFBR2
# TGFB2_ACVR1_TGFBR1
# BMP4_BMPR1A_ACVR2A
# BMP4_BMPR1A_ACVR2B
#                     receptor.transmembrane version
# TGFB2_TGFBR1_TGFBR2 TRUE                   CellChatDB v1
# TGFB2_ACVR1B_TGFBR2 TRUE                   CellChatDB v1
# TGFB2_ACVR1C_TGFBR2 TRUE                   CellChatDB v1
# TGFB2_ACVR1_TGFBR1  TRUE                   CellChatDB v1
# BMP4_BMPR1A_ACVR2A  TRUE                   CellChatDB v1
# BMP4_BMPR1A_ACVR2B  TRUE                   CellChatDB v1

# %%
# Take an input of a ligand-receptor pair
spatialFeaturePlot(cellchat, pairLR.use = "SEMA4D_PLXNB2", sample.use = "control3", point.size = 0.5, do.binary = FALSE, cutoff = 0.05, enriched.only = F, color.heatmap = "Reds", direction = 1)
#> Applying a cutoff of  0.05 to the values...
# Out:
# Applying a cutoff of  0.05 to the values...
# plot without title

# %%
# Take an input of a ligand-receptor pair and show expression in binary
spatialFeaturePlot(cellchat, pairLR.use = "SEMA4D_PLXNB2", sample.use = "control3", point.size = 1.5, do.binary = TRUE, cutoff = 0.05, enriched.only = F, color.heatmap = "Reds", direction = 1)
# Out:
# plot without title

# %%
saveRDS(cellchat, file = "/home/zhangyinan/TXL_new/13_cell_chat/integrate/result/cellchat_control_2.rds")
